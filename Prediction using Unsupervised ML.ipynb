# %% [markdown]
# # Data Science and Business Analytics Intern @ The Sparks Foundation
#
# ## Author : M Sajitha
#
# ## Task 2 : Prediction using Unsupervised ML (Level - Beginner)

# %% [markdown]
# ## Import necessary libraries

# %%
#To import and analyze data
import pandas as pd  

#To perform the multi-dimensional operation
import numpy as np 

#To perform graphical plot into the context
import matplotlib.pyplot as plt

#To visualize data 
import seaborn as sns

print("Libraries imported sucessfully")
# Out:
# Libraries imported sucessfully

# %% [markdown]
# ## Load the iris dataset

# %%
from sklearn import datasets

iris = datasets.load_iris()

iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)

print("Dataset imported sucessfully")
# Out:
# Dataset imported sucessfully

# %% [markdown]
# ### To view first 5 rows of data

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### To view last 5 rows of data

# %%
iris_df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %% [markdown]
# ### To print a concise summary of the DataFrame

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# ### To calculate statistical data

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### To check whether null values are present

# %%
iris_df.isnull == True
# Out:
# False

# %% [markdown]
# ## To find the optimum number of clusters for k-means classification

# %%
x = iris_df.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans

#Within cluster sum of squares
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    
    kmeans.fit(x)
    
    wcss.append(kmeans.inertia_)
    
#To plot the results onto a line graph
plt.plot(range(1, 11), wcss)

plt.title('The elbow method')

plt.xlabel('Number of clusters')

plt.ylabel('WCSS') 

plt.show()
# Out:
# C:\Users\Ramu\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ##### Thus the optimum number of clusters is 3

# %% [markdown]
# ## To create the kmeans classifier

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)

y_kmeans = kmeans.fit_predict(x)

# %% [markdown]
# ## To plot the clusters and its centroids

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')

plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'orange', label = 'Iris-versicolour')

plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')

plt.legend()

# %% [markdown]
# ## Data visualization using different tools

# %% [markdown]
# ### 1. Scatter plot

# %%
iris_df = pd.DataFrame(iris.data,columns=['Sepal Length','Sepal Width', 'Petal Length', 'Petal Width'])

ax = iris_df.plot.scatter(x='Sepal Length',y='Sepal Width',label="Sepal",color='g')

iris_df.plot.scatter(x='Petal Length',y='Petal Width',label="Petal",color='r',ax=ax)

iris_df.plot.scatter(x='Sepal Length',y='Sepal Width',c='Petal Length',s=50)
# Out:
# <AxesSubplot:xlabel='Sepal Length', ylabel='Sepal Width'>

# %% [markdown]
# ### 2. Scatter matrix plot

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(iris_df, alpha=0.2, figsize=(9, 6), diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='Sepal Length', ylabel='Sepal Length'>,
#         <AxesSubplot:xlabel='Sepal Width', ylabel='Sepal Length'>,
#         <AxesSubplot:xlabel='Petal Length', ylabel='Sepal Length'>,
#         <AxesSubplot:xlabel='Petal Width', ylabel='Sepal Length'>],
#        [<AxesSubplot:xlabel='Sepal Length', ylabel='Sepal Width'>,
#         <AxesSubplot:xlabel='Sepal Width', ylabel='Sepal Width'>,
#         <AxesSubplot:xlabel='Petal Length', ylabel='Sepal Width'>,
#         <AxesSubplot:xlabel='Petal Width', ylabel='Sepal Width'>],
#        [<AxesSubplot:xlabel='Sepal Length', ylabel='Petal Length'>,
#         <AxesSubplot:xlabel='Sepal Width', ylabel='Petal Length'>,
#         <AxesSubplot:xlabel='Petal Length', ylabel='Petal Length'>,
#         <AxesSubplot:xlabel='Petal Width', ylabel='Petal Length'>],
#        [<AxesSubplot:xlabel='Sepal Length', ylabel='Petal Width'>,
#         <AxesSubplot:xlabel='Sepal Width', ylabel='Petal Width'>,
# ...

# %% [markdown]
# ### 3. Line plot

# %%
iris_df['target'] = iris.target

iris_df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4. Heatmaps

# %%
sns.heatmap(iris_df.corr(),cmap='rocket_r',annot= True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5. Histogram

# %%
iris_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Sepal Length'}>,
#         <AxesSubplot:title={'center':'Sepal Width'}>],
#        [<AxesSubplot:title={'center':'Petal Length'}>,
#         <AxesSubplot:title={'center':'Petal Width'}>],
#        [<AxesSubplot:title={'center':'target'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### 6. Density plot

# %%
iris_df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 7. Box plot

# %%
iris_df.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### The optimum number of clusters for the given iris dataset is found to be 3. The data is also represented visually through various data visualization tools.

# %% [markdown]
# # Thank you
